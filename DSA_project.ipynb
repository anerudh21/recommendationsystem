# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('/Users/Anerudh/Desktop/MOVIE RECOMMENDATION SYSTEM/dataset.csv', sep = '\t', names = column_names)
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv("/Users/Anerudh/Desktop/MOVIE RECOMMENDATION SYSTEM/movieIdTitles.csv")
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df, movie_titles, on = 'item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
df.groupby('title')['rating'].count().sort_values(ascending = False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['numOfRatings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                              rating  numOfRatings
# title
# 'Til There Was You (1997)  2.333333             9
# 1-900 (1994)               2.600000             5
# 101 Dalmatians (1996)      2.908257           109
# 12 Angry Men (1957)        4.344000           125
# 187 (1997)                 3.024390            41

# %%
plt.figure(figsize = (10,4))
ratings['numOfRatings'].hist(bins = 60)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10,4))
ratings['rating'].hist(bins = 60)
# Out:
# <Axes: >

# %%
sns.jointplot(x='rating', y='numOfRatings', data = ratings, alpha = 0.5)

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
ratings.sort_values('numOfRatings', ascending = False).head(10)
# Out:
#                                  rating  numOfRatings
# title
# Star Wars (1977)               4.359589           584
# Contact (1997)                 3.803536           509
# Fargo (1996)                   4.155512           508
# Return of the Jedi (1983)      4.007890           507
# Liar Liar (1997)               3.156701           485
# English Patient, The (1996)    3.656965           481
# Scream (1996)                  3.441423           478
# Toy Story (1995)               3.878319           452
# Air Force One (1997)           3.631090           431
# Independence Day (ID4) (1996)  3.438228           429

# %%
print('hello')
# Out:
# hello

# %%
ratings.head()
# Out:
#                              rating  numOfRatings FirstMovieRecommendation  \
# title
# 'Til There Was You (1997)  2.333333             9         Edge, The (1997)
# 1-900 (1994)               2.600000             5   Full Monty, The (1997)
# 101 Dalmatians (1996)      2.908257           109    Murder at 1600 (1997)
# 12 Angry Men (1957)        4.344000           125       Ulee's Gold (1997)
# 187 (1997)                 3.024390            41          Maverick (1994)
#
#                                                SecondMovieRecommendation  \
# title
# 'Til There Was You (1997)  William Shakespeare's Romeo and Juliet (1996)
# 1-900 (1994)                                            Crow, The (1994)
# 101 Dalmatians (1996)                      Miracle on 34th Street (1994)
# 12 Angry Men (1957)                                   Rear Window (1954)
# 187 (1997)                                    Conan the Barbarian (1981)
#
# ...

# %%
ratings = ratings.fillna('-')

# %%
ratings.to_csv('MovieRecommendations.csv', encoding='utf-8')

# %%
df_result = pd.read_csv('MovieRecommendations.csv')
df_result.head()
# Out:
#                        title    rating  numOfRatings FirstMovieRecommendation  \
# 0  'Til There Was You (1997)  2.333333             9         Edge, The (1997)
# 1               1-900 (1994)  2.600000             5   Full Monty, The (1997)
# 2      101 Dalmatians (1996)  2.908257           109    Murder at 1600 (1997)
# 3        12 Angry Men (1957)  4.344000           125       Ulee's Gold (1997)
# 4                 187 (1997)  3.024390            41          Maverick (1994)
#
#                        SecondMovieRecommendation  \
# 0  William Shakespeare's Romeo and Juliet (1996)
# 1                               Crow, The (1994)
# 2                  Miracle on 34th Street (1994)
# 3                             Rear Window (1954)
# 4                     Conan the Barbarian (1981)
#
#               ThirdMovieRecommendation       FourthMovieRecommendation
# 0  Star Trek: The Wrath of Khan (1982)                    Dumbo (1941)
# ...

# %%
for i in df_result['title']:
    print(i)
# Out:
# 'Til There Was You (1997)
# 1-900 (1994)
# 101 Dalmatians (1996)
# 12 Angry Men (1957)
# 187 (1997)
# 2 Days in the Valley (1996)
# 20,000 Leagues Under the Sea (1954)
# 2001: A Space Odyssey (1968)
# 3 Ninjas: High Noon At Mega Mountain (1998)
# 39 Steps, The (1935)
# 8 1/2 (1963)
# 8 Heads in a Duffel Bag (1997)
# 8 Seconds (1994)
# A Chef in Love (1996)
# Above the Rim (1994)
# Absolute Power (1997)
# Abyss, The (1989)
# Ace Ventura: Pet Detective (1994)
# Ace Ventura: When Nature Calls (1995)
# Across the Sea of Time (1995)
# Addams Family Values (1993)
# Addicted to Love (1997)
# Addiction, The (1995)
# Adventures of Pinocchio, The (1996)
# Adventures of Priscilla, Queen of the Desert, The (1994)
# Adventures of Robin Hood, The (1938)
# Affair to Remember, An (1957)
# African Queen, The (1951)
# Afterglow (1997)
# Age of Innocence, The (1993)
# Aiqing wansui (1994)
# Air Bud (1997)
# Air Force One (1997)
# Air Up There, The (1994)
# Airheads (1994)
# Akira (1988)
# ...

# %%
x = input()
user_ratings = moviemat[x]
user_ratings.head()
# Out:
# user_id
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Addicted to Love (1997), dtype: float64

# %%
similar = moviemat.corrwith(user_ratings)
# Out:
# /Users/Anerudh/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/Anerudh/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)

# %%
corr = pd.DataFrame(similar,columns=['Correlation'])
corr.dropna(inplace=True)
corr.head()
# Out:
#                              Correlation
# title
# 'Til There Was You (1997)       0.571772
# 101 Dalmatians (1996)          -0.094832
# 12 Angry Men (1957)             0.867722
# 187 (1997)                      0.180756
# 2 Days in the Valley (1996)     0.424471

# %%
corr.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                      Correlation
# title
# Denise Calls Up (1995)                       1.0
# Star Maps (1997)                             1.0
# Oscar & Lucinda (1997)                       1.0
# Blue Chips (1994)                            1.0
# Candidate, The (1972)                        1.0
# Transformers: The Movie, The (1986)          1.0
# Quest, The (1996)                            1.0
# Big Bully (1996)                             1.0
# Adventures of Pinocchio, The (1996)          1.0
# Last Dance (1996)                            1.0

# %%
correlation = corr.join(ratings['numOfRatings'])
correlation.head()
# Out:
#                              Correlation  numOfRatings
# title
# 'Til There Was You (1997)       0.571772             9
# 101 Dalmatians (1996)          -0.094832           109
# 12 Angry Men (1957)             0.867722           125
# 187 (1997)                      0.180756            41
# 2 Days in the Valley (1996)     0.424471            93

# %%
corr[correlation['numOfRatings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                      Correlation
# title
# Ben-Hur (1959)          0.943242
# Little Women (1994)     0.931695
# Patton (1970)           0.894427
# Stargate (1994)         0.875000
# 12 Angry Men (1957)     0.867722
